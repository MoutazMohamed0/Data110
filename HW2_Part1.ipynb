# %% [markdown]
# <a href="https://colab.research.google.com/github/MoutazMohamed0/Data110/blob/main/HW2_Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Anscombe's Quartet:
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
plt.scatter(x, y1)

# %%
# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y1, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y1)
plt.plot(x, regression_line,color='red')
plt.xlabel('x')
plt.ylabel('y1')
# Out:
# Text(0, 0.5, 'y1')

# %%
plt.scatter(x, y2)

# %%
# Your Code need to be here for x and y2
m, b = np.polyfit(x, y2, 1)
plt.scatter(x,y2,color='orange')
plt.plot(x,regression_line)
plt.xlabel('x')
plt.ylabel('y2')
# Out:
# Text(0, 0.5, 'y2')

# %%
plt.scatter(x, y3)

# %%
# Your Code need to be here for x and y3
m, b = np.polyfit(x, y3, 1)
plt.scatter(x,y3,color='green')
plt.plot(x,regression_line)
plt.xlabel('x')
plt.ylabel('y3')
# Out:
# Text(0, 0.5, 'y3')

# %%
plt.scatter(x, y4)

# %%
# Your code need to be here for x and y4
m, b = np.polyfit(x, y4, 1)
plt.scatter(x,y4,color='yellow')
plt.plot(x,regression_line)
plt.xlabel('x')
plt.ylabel('y4')
# Out:
# Text(0, 0.5, 'y4')

# %%
plt.scatter(x4, y4)

# %%
# Your code need to be here for x4 and y4
m, b = np.polyfit(x4, y4, 1)
plt.scatter(x4,y4,color='purple')
plt.plot(x4,regression_line)
plt.xlabel('x4')
plt.ylabel('y4')
# Out:
# Text(0, 0.5, 'y4')

# %% [markdown]
# # Reflection Questions:
#
# 1. How do the datasets visually differ despite having similar summary statistics?
# - Despite having a similar regression line the datasets all show different relationships between their data points, while the other graphs display a more linear relationship between their data points (x4,y4) shows a concentrated set of data points that is significantly effected by the presence of an outlier. Furthermore while the datasets all have similar regression lines the effect of outliers on the regression line differs for each graph, y3 has an outlier at 12.74, y4 has an outlier of 12.5 however their presence does not effect the regression line as significantly as the outlier of 19 at x4 h which has very significant effect on the regression line due to the data points mostly being concentrated at 8.
#
# 2. How did the outlier in the x4, y4 dataset affect the regression line compared to the other datasets?
# - The outlier in the x4, y4 dataset influences the regression line because most of the points are concentrated at 8 however the outlier of 19 skews the regression line upward compared to the other datasets who's data points are more spread out. The outlier of 19 thus has a larger influence on the regression lines position then the other data points on the previous datasets.
#
# 3. Why is it important to visualize data in addition to calculating summary statistics?
# - Visualizing data and calculating summary statistics allows us to more easily see the trends in the data and summarize the relationship between variables in addition it allows the data to be more easily interpreted and disseminated to others who may not be familiar with statistics. Creating an easy to read graph with simple summary statistics makes complex data more easily communicable to those in other fields or the public.
